# %%
# basic operations
import numpy as np
import pandas as pd 

# for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-deep')

# %%
df = pd.read_csv('final_clean_data.csv')

# %%
df.describe()
# Out:
#        Unnamed: 0  Peak Overall    Peak Year    Peak Age    2019 Age  \
# count  639.000000    639.000000   639.000000  639.000000  639.000000
# mean   369.812207     80.255086  2017.589984   27.907668   29.317684
# std    221.447282      3.886199     1.678079    2.699574    2.631051
# min      0.000000     74.000000  2013.000000   19.000000   24.000000
# 25%    171.500000     77.000000  2017.000000   26.000000   27.000000
# 50%    370.000000     80.000000  2018.000000   28.000000   29.000000
# 75%    563.000000     83.000000  2019.000000   30.000000   31.000000
# max    753.000000     94.000000  2019.000000   38.000000   40.000000
#
#               Age     Overall  Expert Potential  International Reputation  \
# count  639.000000  639.000000        639.000000                639.000000
# mean    24.907668   76.101721         79.089202                  1.672926
# std      2.699574    4.856949          4.848151                  0.847864
# ...

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.head()
# Out:
#    Peak Overall  Peak Year  Peak Age  2019 Age  Age  Overall  \
# 0            94       2019        31        31   28       94
# 1            94       2019        33        33   30       93
# 2            92       2019        26        26   23       90
# 3            91       2019        27        27   24       86
# 4            91       2019        27        27   24       88
#
#    Expert Potential Preferred Foot  International Reputation  Weak Foot  ...   \
# 0                94           Left                         5          4  ...
# 1                93          Right                         5          4  ...
# 2                94          Right                         5          5  ...
# 3                89          Right                         3          5  ...
# 4                90          Right                         4          4  ...
#
#    Marking StandingTackle SlidingTackle GKDiving  GKHandling GKKicking  \
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
df.head()
# Out:
#    Peak Overall  Peak Year  Peak Age  2019 Age  Age  Overall  \
# 0            94       2019        31        31   28       94
# 1            94       2019        33        33   30       93
# 2            92       2019        26        26   23       90
# 3            91       2019        27        27   24       86
# 4            91       2019        27        27   24       88
#
#    Expert Potential Preferred Foot  International Reputation  Weak Foot  \
# 0                94           Left                         5          4
# 1                93          Right                         5          4
# 2                94          Right                         5          5
# 3                89          Right                         3          5
# 4                90          Right                         4          4
#
#    Skill Moves   Body Type Real Face Position  Jersey Number        Joined  \
# 0            4       Messi       Yes       RW             10   Jul 1, 2004
# ...

# %%
df.columns
# Out:
# Index(['Peak Overall', 'Peak Year', 'Peak Age', '2019 Age', 'Age', 'Overall',
#        'Expert Potential', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
# ...

# %%
columns_to_keep = ['Peak Overall', 'Age', 'Overall', 'centimeter height', 'Weight', 
       'Expert Potential', 'International Reputation',
       'Weak Foot', 'Skill Moves',
       'Crossing', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
       'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
       'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Marking', 'StandingTackle', 'SlidingTackle', 'ID', 'Year']

# %%
df.head()
# Out:
#    Peak Overall  Peak Year  Peak Age  2019 Age  Age  Overall  \
# 0            94       2019        31        31   28       94
# 1            94       2019        33        33   30       93
# 2            92       2019        26        26   23       90
# 3            91       2019        27        27   24       86
# 4            91       2019        27        27   24       88
#
#    Expert Potential Preferred Foot  International Reputation  Weak Foot  \
# 0                94           Left                         5          4
# 1                93          Right                         5          4
# 2                94          Right                         5          5
# 3                89          Right                         3          5
# 4                90          Right                         4          4
#
#    Skill Moves   Body Type Real Face Position  Jersey Number        Joined  \
# 0            4       Messi       Yes       RW             10   Jul 1, 2004
# ...

# %%
df_clean = df[columns_to_keep]

# %%
df_clean.head()
# Out:
#    Peak Overall  Age  Overall  centimeter height  Weight  Expert Potential  \
# 0            94   28       94             170.18     159                94
# 1            94   30       93             185.42     176                93
# 2            92   23       90             175.26     150                94
# 3            91   24       86             180.34     168                89
# 4            91   24       88             172.72     163                90
#
#    International Reputation  Weak Foot  Skill Moves  Crossing  Finishing  \
# 0                         5          4            4        80         93
# 1                         5          4            5        82         95
# 2                         5          5            5        72         88
# 3                         3          5            4        90         82
# 4                         4          4            4        80         81
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# ...

# %%
table_1 = df_clean.describe().transpose()

# %%
table_1.to_csv('describe.csv')

# %%
df_clean.dtypes
# Out:
# Peak Overall                  int64
# Age                           int64
# Overall                       int64
# centimeter height           float64
# Weight                        int32
# Expert Potential              int64
# International Reputation      int64
# Weak Foot                     int64
# Skill Moves                   int64
# Crossing                      int64
# Finishing                     int64
# HeadingAccuracy               int64
# ShortPassing                  int64
# Volleys                       int64
# Dribbling                     int64
# Curve                         int64
# FKAccuracy                    int64
# LongPassing                   int64
# BallControl                   int64
# Acceleration                  int64
# SprintSpeed                   int64
# Agility                       int64
# Reactions                     int64
# Balance                       int64
# ShotPower                     int64
# Jumping                       int64
# ...

# %%
df_clean.to_csv('Model_data.csv')

# %%
df['Preferred Foot'].value_counts().head(50).plot.bar(color = 'purple')
plt.title('Most Preferred Foot of the Players', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Most Preferred Foot of the Players')

# %%
# comparing the performance of left-footed and right-footed footballers
# ballcontrol vs dribbing

sns.lmplot(x = 'BallControl', y = 'Dribbling', data = df, col = 'Preferred Foot')
# Out:
# d:\professional\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
def parse_height(strVal):
    a, b = strVal.split("'")
    height = int(a) * 30.48 + int(b) * 2.54
    return height

# %%
df['centimeter height'] = round(df['Height'].apply(lambda x: parse_height(x)),2)

# %%
plt.figure(figsize = (13, 8))
ax = sns.countplot(x = 'centimeter height', data = df, palette = 'dark')
ax.set_title(label = 'Count of players on Basis of Height', fontsize = 20)
ax.set_xlabel(xlabel = 'Height in Centimer', fontsize = 16)
ax.set_ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %%
df['Weight'] = df['Weight'].str.replace('lbs', '')

# %%
# To show Different body weight of the players participating in the FIFA 2019

plt.figure(figsize = (30, 8))
sns.countplot(x = 'Weight', data = df, palette = 'rainbow')
plt.title('Different Weights of the Players', fontsize = 20)
plt.xlabel('Weights associated with the players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()

# %%
from scipy.stats import norm

# %%
df['Expert Potential'].mean()
# Out:
# 79.08920187793427

# %%
plt.figure(figsize=(12,8))
plt.hist(df['Expert Potential'], bins=20, normed=True, alpha=0.6, color='g')
plt.title('Histogram of Experts\' guess of players Potential Scores', fontsize = 20)
plt.xlabel("Player\'s Potential Scores", fontsize = 16)
plt.ylabel('Number of players', fontsize = 16)
 
# Plot the probability density function for norm
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, df['Expert Potential'].mean(), df['Expert Potential'].std())
plt.plot(x, p, 'k', linewidth=2, color='r')
plt.title('Histogram of Experts\' guess of players Potential Scores', fontsize = 20)

plt.show()
# Out:
# d:\professional\python3\lib\site-packages\matplotlib\axes\_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# To show Different potential scores of the players participating in the FIFA 2019

x = df['Expert Potential']
plt.figure(figsize=(12,8))
ax = sns.distplot(x, bins = 20, kde = False, color = 'y')
ax.set_xlabel(xlabel = "Player\'s Potential Scores", fontsize = 16)
ax.set_ylabel(ylabel = 'Number of players', fontsize = 16)
ax.set_title(label = 'Histogram of Experts\' guess of players Potential Scores', fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.hist(df['Peak Overall'], bins=20, normed=True, alpha=0.6, color='purple')
plt.title('Histogram of players Peak Overall Scores', fontsize = 20)
plt.xlabel("Player\'s Peak Scores", fontsize = 16)
plt.ylabel('Number of players', fontsize = 16)
 
# Plot the probability density function for norm
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, df['Peak Overall'].mean(), df['Expert Potential'].std())
plt.plot(x, p, 'k', linewidth=2, color='b')
plt.title('Histogram of players Peak Overall Scores', fontsize = 20)

plt.show()
# Out:
# d:\professional\python3\lib\site-packages\matplotlib\axes\_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# To show that there are people having same age
# Histogram: number of players's age

sns.set(style = "dark", palette = "colorblind", color_codes = True)
x = df['Peak Age']
plt.figure(figsize = (12,8))
ax = sns.distplot(x, bins = 20, kde = False, color = 'g')
ax.set_xlabel(xlabel = "Player\'s age", fontsize = 16)
ax.set_ylabel(ylabel = 'Number of players', fontsize = 16)
ax.set_title(label = 'Histogram of players age', fontsize = 20)
plt.show()

# %%
# plotting a correlation heatmap

plt.rcParams['figure.figsize'] = (30, 20)
sns.heatmap(df[['Peak Overall', 'Peak Year', 'Peak Age', 'Overall',
       'Expert Potential', 'Preferred Foot', 'International Reputation',
       'Weak Foot', 'Skill Moves',
       'Jersey Number', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
       'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
       'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
       'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
       'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
       'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']].corr(), annot = True)

plt.title('Histogram of the Dataset', fontsize = 30)
plt.show()

# %%
# plotting a clean correlation heatmap

plt.rcParams['figure.figsize'] = (30, 20)
sns.heatmap(df[['Peak Overall', 'Age', 'Overall',
       'Expert Potential', 'International Reputation',
       'Weak Foot', 'Skill Moves', 'Position',
       'Crossing', 'Finishing', 'HeadingAccuracy',
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
       'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
       'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Marking', 'StandingTackle', 'SlidingTackle']].corr(), annot = True)

plt.title('Correlation Heatmap of the Dataset', fontsize = 30)
plt.show()
plt.savefig('heatmap.png')
